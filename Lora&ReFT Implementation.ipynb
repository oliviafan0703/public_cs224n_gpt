# %%
# !unzip public_cs224n_gpt_new.zip
# Out:
# Archive:  public_cs224n_gpt_new.zip
#    creating: public_cs224n_gpt_new/
#   inflating: __MACOSX/._public_cs224n_gpt_new
#   inflating: public_cs224n_gpt_new/setup.sh
#   inflating: __MACOSX/public_cs224n_gpt_new/._setup.sh
#   inflating: public_cs224n_gpt_new/optimizer_test.py
#   inflating: __MACOSX/public_cs224n_gpt_new/._optimizer_test.py
#   inflating: public_cs224n_gpt_new/classifier.py
#   inflating: __MACOSX/public_cs224n_gpt_new/._classifier.py
#   inflating: public_cs224n_gpt_new/.DS_Store
#   inflating: __MACOSX/public_cs224n_gpt_new/._.DS_Store
#   inflating: public_cs224n_gpt_new/config.py
#   inflating: __MACOSX/public_cs224n_gpt_new/._config.py
#   inflating: public_cs224n_gpt_new/LICENSE
#   inflating: __MACOSX/public_cs224n_gpt_new/._LICENSE
#   inflating: public_cs224n_gpt_new/paraphrase_detection.py
#   inflating: __MACOSX/public_cs224n_gpt_new/._paraphrase_detection.py
#   inflating: public_cs224n_gpt_new/evaluation.py
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/
# !ls
# !unzip public_cs224n_gpt.zip
# Out:
# /content/drive/MyDrive
# 'CS224N Default Project Milestone.ipynb'   __MACOSX   public_cs224n_gpt_new   public_cs224n_gpt.zip
# Archive:  public_cs224n_gpt.zip
#    creating: public_cs224n_gpt/
#   inflating: __MACOSX/._public_cs224n_gpt
#   inflating: public_cs224n_gpt/setup.sh
#   inflating: __MACOSX/public_cs224n_gpt/._setup.sh
#   inflating: public_cs224n_gpt/optimizer_test.py
#   inflating: __MACOSX/public_cs224n_gpt/._optimizer_test.py
#   inflating: public_cs224n_gpt/classifier.py
#   inflating: __MACOSX/public_cs224n_gpt/._classifier.py
#   inflating: public_cs224n_gpt/.DS_Store
#   inflating: __MACOSX/public_cs224n_gpt/._.DS_Store
#   inflating: public_cs224n_gpt/config.py
#   inflating: __MACOSX/public_cs224n_gpt/._config.py
#   inflating: public_cs224n_gpt/LICENSE
#   inflating: __MACOSX/public_cs224n_gpt/._LICENSE
#   inflating: public_cs224n_gpt/paraphrase_detection.py
#   inflating: __MACOSX/public_cs224n_gpt/._paraphrase_detection.py
# ...

# %%
# !pip install torch torchvision torchaudio tqdm requests importlib-metadata filelock sklearn==0.0 tokenizers==0.20 explainaboard_client==0.0.7 einops==0.8.0 transformers==4.46.3 sacrebleu==2.5.1

# %%
# %cd public_cs224n_gpt/
# !ls
# Out:
# /content/drive/MyDrive/public_cs224n_gpt
# classifier.py  evaluation.py  optimizer_test.npy       __pycache__	     utils.py
# config.py      LICENSE	      optimizer_test.py        README.md
# data	       models	      paraphrase_detection.py  sanity_check.py
# datasets.py    modules	      predictions	       setup.sh
# env.yml        optimizer.py   prepare_submit.py        sonnet_generation.py

# %%
# !python paraphrase_detection.py --use_gpu --use_lora
# Out:
# 2025-02-26 21:42:24.435475: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-26 21:42:24.453257: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740606144.475277  221952 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740606144.481986  221952 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python paraphrase_detection.py --use_gpu --use_reft
# Out:
# 2025-02-27 02:15:14.304897: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-27 02:15:14.322571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740622514.344298  289525 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740622514.350919  289525 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
